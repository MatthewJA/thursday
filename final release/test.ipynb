# %%
from format_data import get_data, data_pregen, data_gen
from model_sklearn import model_sklearn
import keras 
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
seed = 0

first_path = r"data.h5"
second_path = "asu.tsv"

flatten = True

# %%
train_x, train_y, test_x, test_y = get_data(first_path, second_path, 
                                            flip_train_test=False, dim=256, conf_matrix = True, seed=seed)
# Out:
# C:\Users\fires\Anaconda3\envs\CSIRO\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\fires\Anaconda3\envs\CSIRO\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\fires\Anaconda3\envs\CSIRO\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# C:\Users\fires\Anaconda3\envs\CSIRO\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
# ...

# %%
datagen = data_gen(rotation_range=180, zoom_range=0.2, shift_range = 0.0, flip=True)

# %%
train_x, train_y, test_x, test_y = data_pregen(train_x, train_y, test_x, test_y, datagen=datagen, batch_size=2, nb_epoch=10, seed=seed)

# %%
params = {'n_estimators': 1000, 'criterion':'gini'}

# %%
model = model_sklearn(train_x, train_y, RandomForestClassifier, params)

# %%
test_x = test_x.reshape((test_x.shape[0], -1))

model.score(test_x, test_y)
# Out:
# 1.0
